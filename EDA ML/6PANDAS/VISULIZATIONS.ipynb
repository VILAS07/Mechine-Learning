# %%
import matplotlib.pyplot as plt
x=[2,2,2,2,2,2,2,2,2,2,2,5,6,8,2]
plt.hist(x)
plt.show()

# %%
x=[2,4,3,5]
label=['apple','orange','grapes','kiwi']
plt.pie(x,labels=label,autopct='%1.1f%%')
plt.legend(label)
plt.show()
